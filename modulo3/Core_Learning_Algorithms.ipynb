# %% [markdown]
# # TensorFlow Core Learning Algorithms
# In this notebook we will walk through 4 fundemental machine learning algorithms. We will apply each of these algorithms to unique problems and datasets before highlighting the use cases of each.
#
# The algorithms we will focus on include:
# - Linear Regression
# - Classification
# - Clustering
# - Hidden Markov Models
#
# It is worth noting that there are many tools within TensorFlow that could be used to solve the problems we will see below. I have chosen the tools that I belive give the most variety and are easiest to use.

# %% [markdown]
# ## Linear Regression
# Linear regression is one of the most basic forms of machine learning and is used to predict numeric values.
#
# In this tutorial we will use a linear model to predict the survival rate of passangers from the titanic dataset.
#
# *This section is based on the following documentation: https://www.tensorflow.org/tutorials/estimator/linear*

# %% [markdown]
# ### How it Works
# Before we dive in, I will provide a very surface level explination of the linear regression algorithm.
#
# Linear regression follows a very simple concept. If data points are related linearly, we can generate a line of best fit for these points and use it to predict future values.
#
# Let's take an example of a data set with one feature and one label.

# %%
import matplotlib.pyplot as plt
import numpy as np

x = [1, 2, 2.5, 3, 4]
y = [1, 4, 7, 9, 15]
plt.plot(x, y, 'ro')
plt.axis([2, 6, 0, 20])
# Out:
# (2.0, 6.0, 0.0, 20.0)

# %% [markdown]
# We can see that this data has a linear coorespondence. When the x value increases, so does the y. Because of this relation we can create a line of best fit for this dataset. In this example our line will only use one input variable, as we are working with two dimensions. In larger datasets with more features our line will have more features and inputs.
#
# "Line of best fit refers to a line through a scatter plot of data points that best expresses the relationship between those points." (https://www.investopedia.com/terms/l/line-of-best-fit.asp)
#
# Here's a refresher on the equation of a line in 2D.
#
# $ y = mx + b $
#
# Here's an example of a line of best fit for this graph.

# %%
plt.plot(x, y, 'ro')
plt.axis([0, 6, 0, 20])
plt.plot(np.unique(x), np.poly1d(np.polyfit(x, y, 1))(np.unique(x)))
plt.show()

# %% [markdown]
# Once we've generated this line for our dataset, we can use its equation to predict future values. We just pass the features of the data point we would like to predict into the equation of the line and use the output as our prediction.

# %% [markdown]
# ### Setup and Imports
# Before we get started we must install *sklearn* and import the following modules.

# %%
# %pip install -q sklearn
# Out:
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.1.3; however, version 22.2.2 is available.
# You should consider upgrading via the 'c:\Users\samgar\Desktop\Samuel\tensorflow\.venv\Scripts\python.exe -m pip install --upgrade pip' command.

# %%
# %tensorflow_version 2.x  # this line is not required unless you are in a notebook
# Out:
# UsageError: Line magic function `%tensorflow_version` not found.

# %%
from __future__ import absolute_import, division, print_function, unicode_literals

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import clear_output
from six.moves import urllib

import tensorflow.compat.v2.feature_column as fc

import tensorflow as tf

# %% [markdown]
# ### Data
# So, if you haven't realized by now a major part of machine learning is data! In fact, it's so important that most of what we do in this tutorial will focus on exploring, cleaning and selecting appropriate data.
#
# The dataset we will be focusing on here is the titanic dataset. It has tons of information about each passanger on the ship. Our first step is always to understand the data and explore it. So, let's do that!
#
# **Below we will load a dataset and learn how we can explore it using some built-in tools.**

# %%
# Load dataset.
dftrain = pd.read_csv('https://storage.googleapis.com/tf-datasets/titanic/train.csv') # training data
dfeval = pd.read_csv('https://storage.googleapis.com/tf-datasets/titanic/eval.csv') # testing data
y_train = dftrain.pop('survived') # removes 'survived' field and stores it in y_train variable
y_eval = dfeval.pop('survived')

# %% [markdown]
# The ```pd.read_csv()``` method will return to us a new pandas *dataframe*. You can think of a dataframe like a table. In fact, we can actually have a look at the table representation.
#
# We've decided to pop the "survived" column from our dataset and store it in a new variable. This column simply tells us if the person survived our not.
#
# To look at the data we'll use the ```.head()``` method from pandas. This will show us the first 5 items in our dataframe.

# %%
dftrain.head()
# Out:
#       sex   age  n_siblings_spouses  parch     fare  class     deck  \
# 0    male  22.0                   1      0   7.2500  Third  unknown
# 1  female  38.0                   1      0  71.2833  First        C
# 2  female  26.0                   0      0   7.9250  Third  unknown
# 3  female  35.0                   1      0  53.1000  First        C
# 4    male  28.0                   0      0   8.4583  Third  unknown
#
#    embark_town alone
# 0  Southampton     n
# 1    Cherbourg     n
# 2  Southampton     y
# 3  Southampton     n
# 4   Queenstown     y

# %% [markdown]
# And if we want a more statistical analysis of our data we can use the ```.describe()``` method.

# %%
dftrain.describe()
# Out:
#               age  n_siblings_spouses       parch        fare
# count  627.000000          627.000000  627.000000  627.000000
# mean    29.631308            0.545455    0.379585   34.385399
# std     12.511818            1.151090    0.792999   54.597730
# min      0.750000            0.000000    0.000000    0.000000
# 25%     23.000000            0.000000    0.000000    7.895800
# 50%     28.000000            0.000000    0.000000   15.045800
# 75%     35.000000            1.000000    0.000000   31.387500
# max     80.000000            8.000000    5.000000  512.329200

# %% [markdown]
# And since we talked so much about shapes in the previous tutorial let's have a look at that too!

# %%
dftrain.shape
# Out:
# (627, 9)

# %% [markdown]
# So have have 627 entries and 9 features, nice!
#
# Now let's have a look at our survival information.

# %%
y_train.head()
# Out:
# 0    0
# 1    1
# 2    1
# 3    1
# 4    0
# Name: survived, dtype: int64

# %% [markdown]
# Notice that each entry is either a 0 or 1. Can you guess which stands for survival?
#
# **And now because visuals are always valuable let's generate a few graphs of the data.**

# %%
dftrain.age.hist(bins=20)
# Out:
# <AxesSubplot:>

# %%
dftrain.sex.value_counts().plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
dftrain['class'].value_counts().plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
pd.concat([dftrain, y_train], axis=1).groupby('sex').survived.mean().plot(kind='barh').set_xlabel('% survive')
# Out:
# Text(0.5, 0, '% survive')

# %% [markdown]
# After analyzing this information, we should notice the following:
# - Most passengers are in their 20's or 30's
# - Most passengers are male
# - Most passengers are in "Third" class
# - Females have a much higher chance of survival

# %% [markdown]
# ### Training vs Testing Data
# You may have noticed that we loaded **two different datasets** above. This is because when we train models, we need two sets of data: **training and testing**.
#
# The **training** data is what we feed to the model so that it can develop and learn. It is usually a much larger size than the testing data.
#
# The **testing** data is what we use to evaulate the model and see how well it is performing. We must use a seperate set of data that the model has not been trained on to evaluate it. Can you think of why this is?
#
# Well, the point of our model is to be able to make predictions on NEW data, data that we have never seen before. If we simply test the model on the data that it has already seen we cannot measure its accuracy accuratly. We can't be sure that the model hasn't simply memorized our training data. This is why we need our testing and training data to be seperate.

# %% [markdown]
# ### Feature Columns
# In our dataset we have two different kinds of information: **Categorical and Numeric**
#
# Our **categorical data** is anything that is not numeric! For example, the sex column does not use numbers, it uses the words "male" and "female".
#
# Before we continue and create/train a model we must convet our categorical data into numeric data. We can do this by encoding each category with an integer (ex. male = 1, female = 2).
#
# Fortunately for us TensorFlow has some tools to help!

# %%
CATEGORICAL_COLUMNS = ['sex', 'n_siblings_spouses', 'parch', 'class', 'deck',
                       'embark_town', 'alone']
NUMERIC_COLUMNS = ['age', 'fare']

feature_columns = []
for feature_name in CATEGORICAL_COLUMNS:
  vocabulary = dftrain[feature_name].unique()  # gets a list of all unique values from given feature column
  feature_columns.append(tf.feature_column.categorical_column_with_vocabulary_list(feature_name, vocabulary))

for feature_name in NUMERIC_COLUMNS:
  feature_columns.append(tf.feature_column.numeric_column(feature_name, dtype=tf.float32))

print(feature_columns)
# Out:
# [VocabularyListCategoricalColumn(key='sex', vocabulary_list=('male', 'female'), dtype=tf.string, default_value=-1, num_oov_buckets=0), VocabularyListCategoricalColumn(key='n_siblings_spouses', vocabulary_list=(1, 0, 3, 4, 2, 5, 8), dtype=tf.int64, default_value=-1, num_oov_buckets=0), VocabularyListCategoricalColumn(key='parch', vocabulary_list=(0, 1, 2, 5, 3, 4), dtype=tf.int64, default_value=-1, num_oov_buckets=0), VocabularyListCategoricalColumn(key='class', vocabulary_list=('Third', 'First', 'Second'), dtype=tf.string, default_value=-1, num_oov_buckets=0), VocabularyListCategoricalColumn(key='deck', vocabulary_list=('unknown', 'C', 'G', 'A', 'B', 'D', 'F', 'E'), dtype=tf.string, default_value=-1, num_oov_buckets=0), VocabularyListCategoricalColumn(key='embark_town', vocabulary_list=('Southampton', 'Cherbourg', 'Queenstown', 'unknown'), dtype=tf.string, default_value=-1, num_oov_buckets=0), VocabularyListCategoricalColumn(key='alone', vocabulary_list=('n', 'y'), dtype=tf.string, default_value=-1, num_oov_buckets=0), NumericColumn(key='age', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), NumericColumn(key='fare', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None)]

# %% [markdown]
# Let's break this code down a little bit...
#
# Essentially what we are doing here is creating a list of features that are used in our dataset.
#
# The cryptic lines of code inside the ```append()``` create an object that our model can use to map string values like "male" and "female" to integers. This allows us to avoid manually having to encode our dataframes.
#
# *And here is some relevant documentation*
#
# https://www.tensorflow.org/api_docs/python/tf/feature_column/categorical_column_with_vocabulary_list?version=stable

# %% [markdown]
# ### The Training Process
# So, we are almost done preparing our dataset and I feel as though it's a good time to explain how our model is trained. Specifically, how input data is fed to our model.
#
# For this specific model data is going to be streamed into it in small batches of 32. This means we will not feed the entire dataset to our model at once, but simply small batches of entries. We will feed these batches to our model multiple times according to the number of **epochs**.
#
# An **epoch** is simply one stream of our entire dataset. The number of epochs we define is the amount of times our model will see the entire dataset. We use multiple epochs in hope that after seeing the same data multiple times the model will better determine how to estimate it.
#
# Ex. if we have 10 ephocs, our model will see the same dataset 10 times.
#
# Since we need to feed our data in batches and multiple times, we need to create something called an **input function**. The input function simply defines how our dataset will be converted into batches at each epoch.

# %% [markdown]
# ### Input Function
# The TensorFlow model we are going to use requires that the data we pass it comes in as a ```tf.data.Dataset``` object. This means we must create a *input function* that can convert our current pandas dataframe into that object.
#
# Below you'll see a seemingly complicated input function, this is straight from the TensorFlow documentation (https://www.tensorflow.org/tutorials/estimator/linear). I've commented as much as I can to make it understandble, but you may want to refer to the documentation for a detailed explination of each method.

# %%
def make_input_fn(data_df, label_df, num_epochs=10, shuffle=True, batch_size=32):
  def input_function():  # inner function, this will be returned
    ds = tf.data.Dataset.from_tensor_slices((dict(data_df), label_df))  # create tf.data.Dataset object with data and its label
    if shuffle:
      ds = ds.shuffle(1000)  # randomize order of data
    ds = ds.batch(batch_size).repeat(num_epochs)  # split dataset into batches of 32 and repeat process for number of epochs
    return ds  # return a batch of the dataset
  return input_function  # return a function object for use

train_input_fn = make_input_fn(dftrain, y_train)  # here we will call the input_function that was returned to us to get a dataset object we can feed to the model
eval_input_fn = make_input_fn(dfeval, y_eval, num_epochs=1, shuffle=False)

# %% [markdown]
# ### Creating the Model
# In this tutorial we are going to use a linear estimator to utilize the linear regression algorithm.
#
# Creating one is pretty easy! Have a look below.

# %%
linear_est = tf.estimator.LinearClassifier(feature_columns=feature_columns)
# We create a linear estimtor by passing the feature columns we created earlier
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: C:\Users\samgar\AppData\Local\Temp\tmp91d20vit
# INFO:tensorflow:Using config: {'_model_dir': 'C:\\Users\\samgar\\AppData\\Local\\Temp\\tmp91d20vit', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_checkpoint_save_graph_def': True, '_service': None, '_cluster_spec': ClusterSpec({}), '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}

# %% [markdown]
# ### Training the Model
# Training the model is as easy as passing the input functions that we created earlier.

# %%
linear_est.train(train_input_fn)  # train
result = linear_est.evaluate(eval_input_fn)  # get model metrics/stats by testing on tetsing data
clear_output()  # clears console output
from time import sleep # solo para que imprima lo de abajo en vscode
sleep(0.1)
print(result['accuracy'])  # the result variable is simply a dict of stats about our model
print(result)
# Out:
# 0.71590906
# {'accuracy': 0.71590906, 'accuracy_baseline': 0.625, 'auc': 0.81744725, 'auc_precision_recall': 0.7590085, 'average_loss': 0.63983107, 'label/mean': 0.375, 'loss': 0.6448016, 'precision': 0.5869565, 'prediction/mean': 0.5675639, 'recall': 0.8181818, 'global_step': 200}

# %% [markdown]
# And we now we have a model with a ~75% accuracy (this will change each time)! Not crazy impressive but decent for our first try.
#
# Now let's see how we can actually use this model to make predicitons.
#
# We can use the ```.predict()``` method to get survival probabilities from the model. This method will return a list of dicts that store a predicition for each of the entries in our testing data set. Below we've used some pandas magic to plot a nice graph of the predictions.
#
# As you can see the survival rate is not very high :/

# %%
pred_dicts = list(linear_est.predict(eval_input_fn))
probs = pd.Series([pred['probabilities'][1] for pred in pred_dicts]) # probabilites[1] = chance of survival
 
probs.plot(kind='hist', bins=20, title='predicted probabilities')
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from C:\Users\samgar\AppData\Local\Temp\tmp91d20vit\model.ckpt-200
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# <AxesSubplot:title={'center':'predicted probabilities'}, ylabel='Frequency'>

# %% [markdown]
# That's it for linear regression! Now onto classification.

# %% [markdown]
# ## Classification
# Now that we've covered linear regression it is time to talk about classification. Where regression was used to predict a numeric value, classification is used to seperate data points into classes of different labels. In this example we will use a TensorFlow estimator to classify flowers.
#
# Since we've touched on how estimators work earlier, I'll go a bit quicker through this example.
#
# This section is based on the following guide from the TensorFlow website.
# https://www.tensorflow.org/tutorials/estimator/premade

# %% [markdown]
# ### Imports and Setup

# %%
# %tensorflow_version 2.x  # this line is not required unless you are in a notebook
# Out:
# UsageError: Line magic function `%tensorflow_version` not found.

# %%
from __future__ import absolute_import, division, print_function, unicode_literals


import tensorflow as tf

import pandas as pd

# %% [markdown]
# ### Dataset
# This specific dataset seperates flowers into 3 different classes of species.
# - Setosa
# - Versicolor
# - Virginica
#
# The information about each flower is the following.
# - sepal length
# - sepal width
# - petal length
# - petal width

# %%
CSV_COLUMN_NAMES = ['SepalLength', 'SepalWidth', 'PetalLength', 'PetalWidth', 'Species']
SPECIES = ['Setosa', 'Versicolor', 'Virginica']
# Lets define some constants to help us later on

# %%
train_path = tf.keras.utils.get_file(
    "iris_training.csv", "https://storage.googleapis.com/download.tensorflow.org/data/iris_training.csv")
test_path = tf.keras.utils.get_file(
    "iris_test.csv", "https://storage.googleapis.com/download.tensorflow.org/data/iris_test.csv")

train = pd.read_csv(train_path, names=CSV_COLUMN_NAMES, header=0)
test = pd.read_csv(test_path, names=CSV_COLUMN_NAMES, header=0)
# Here we use keras (a module inside of TensorFlow) to grab our datasets and read them into a pandas dataframe

# %% [markdown]
# Let's have a look at our data.

# %%
train.head()
# Out:
#    SepalLength  SepalWidth  PetalLength  PetalWidth  Species
# 0          6.4         2.8          5.6         2.2        2
# 1          5.0         2.3          3.3         1.0        1
# 2          4.9         2.5          4.5         1.7        2
# 3          4.9         3.1          1.5         0.1        0
# 4          5.7         3.8          1.7         0.3        0

# %% [markdown]
# Now we can pop the species column off and use that as our label.

# %%
train_y = train.pop('Species')
test_y = test.pop('Species')
train.head() # the species column is now gone
# Out:
#    SepalLength  SepalWidth  PetalLength  PetalWidth
# 0          6.4         2.8          5.6         2.2
# 1          5.0         2.3          3.3         1.0
# 2          4.9         2.5          4.5         1.7
# 3          4.9         3.1          1.5         0.1
# 4          5.7         3.8          1.7         0.3

# %%
train.shape  # we have 120 entires with 4 features
# Out:
# (120, 4)

# %% [markdown]
# ### Input Function
# Remember that nasty input function we created earlier. Well we need to make another one here! Fortunatly for us this one is a little easier to digest.

# %%
def input_fn(features, labels, training=True, batch_size=256):
    # Convert the inputs to a Dataset.
    dataset = tf.data.Dataset.from_tensor_slices((dict(features), labels))

    # Shuffle and repeat if you are in training mode.
    if training:
        dataset = dataset.shuffle(1000).repeat()
    
    return dataset.batch(batch_size)

# %% [markdown]
# ### Feature Columns
# And you didn't think we forgot about the feature columns, did you?

# %%
# Feature columns describe how to use the input.
my_feature_columns = []
for key in train.keys():
    my_feature_columns.append(tf.feature_column.numeric_column(key=key))
print(my_feature_columns)
# Out:
# [NumericColumn(key='SepalLength', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), NumericColumn(key='SepalWidth', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), NumericColumn(key='PetalLength', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), NumericColumn(key='PetalWidth', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None)]

# %% [markdown]
# ### Building the Model
# And now we are ready to choose a model. For classification tasks there are variety of different estimators/models that we can pick from. Some options are listed below.
# - ```DNNClassifier``` (Deep Neural Network)
# - ```LinearClassifier```
#
# We can choose either model but the DNN seems to be the best choice. This is because we may not be able to find a linear coorespondence in our data.
#
# So let's build a model!

# %%
# Build a DNN with 2 hidden layers with 30 and 10 hidden nodes each.
classifier = tf.estimator.DNNClassifier(
    feature_columns=my_feature_columns,
    # Two hidden layers of 30 and 10 nodes respectively.
    hidden_units=[30, 10],
    # The model must choose between 3 classes.
    n_classes=3)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: C:\Users\samgar\AppData\Local\Temp\tmps_ybtmm1
# INFO:tensorflow:Using config: {'_model_dir': 'C:\\Users\\samgar\\AppData\\Local\\Temp\\tmps_ybtmm1', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_checkpoint_save_graph_def': True, '_service': None, '_cluster_spec': ClusterSpec({}), '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}

# %% [markdown]
# What we've just done is created a deep neural network that has two hidden layers. These layers have 30 and 10 neurons respectively. This is the number of neurons the TensorFlow official tutorial uses so we'll stick with it. However, it is worth mentioning that the number of hidden neurons is an arbitrary number and many experiments and tests are usually done to determine the best choice for these values. Try playing around with the number of hidden neurons and see if your results change.

# %% [markdown]
# ### Training
# Now it's time to train the model!

# %%
classifier.train(
    input_fn=lambda: input_fn(train, train_y, training=True),
    steps=30000)
# We include a lambda to avoid creating an inner function previously
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 0...
# INFO:tensorflow:Saving checkpoints for 0 into C:\Users\samgar\AppData\Local\Temp\tmps_ybtmm1\model.ckpt.
# INFO:tensorflow:C:\Users\samgar\AppData\Local\Temp\tmps_ybtmm1\model.ckpt-0.data-00000-of-00001
# INFO:tensorflow:0
# INFO:tensorflow:C:\Users\samgar\AppData\Local\Temp\tmps_ybtmm1\model.ckpt-0.index
# INFO:tensorflow:0
# INFO:tensorflow:C:\Users\samgar\AppData\Local\Temp\tmps_ybtmm1\model.ckpt-0.meta
# INFO:tensorflow:100
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 0...
# INFO:tensorflow:loss = 1.3919306, step = 0
# INFO:tensorflow:global_step/sec: 435.189
# INFO:tensorflow:loss = 1.0592754, step = 100 (0.231 sec)
# INFO:tensorflow:global_step/sec: 633.058
# INFO:tensorflow:loss = 0.98022825, step = 200 (0.157 sec)
# INFO:tensorflow:global_step/sec: 645.161
# INFO:tensorflow:loss = 0.92236805, step = 300 (0.158 sec)
# INFO:tensorflow:global_step/sec: 538.054
# INFO:tensorflow:loss = 0.8772477, step = 400 (0.185 sec)
# INFO:tensorflow:global_step/sec: 591.618
# INFO:tensorflow:loss = 0.84472936, step = 500 (0.168 sec)
# INFO:tensorflow:global_step/sec: 537.856
# INFO:tensorflow:loss = 0.81637424, step = 600 (0.185 sec)
# INFO:tensorflow:global_step/sec: 558.725
# INFO:tensorflow:loss = 0.78924954, step = 700 (0.181 sec)
# INFO:tensorflow:global_step/sec: 588.393
# INFO:tensorflow:loss = 0.76171196, step = 800 (0.168 sec)
# INFO:tensorflow:global_step/sec: 606.161
# INFO:tensorflow:loss = 0.7453264, step = 900 (0.165 sec)
# INFO:tensorflow:global_step/sec: 623.138
# INFO:tensorflow:loss = 0.72552836, step = 1000 (0.160 sec)
# INFO:tensorflow:global_step/sec: 588.32
# INFO:tensorflow:loss = 0.69815266, step = 1100 (0.171 sec)
# INFO:tensorflow:global_step/sec: 637.085
# INFO:tensorflow:loss = 0.6883654, step = 1200 (0.156 sec)
# INFO:tensorflow:global_step/sec: 641.142
# INFO:tensorflow:loss = 0.665148, step = 1300 (0.156 sec)
# INFO:tensorflow:global_step/sec: 633.015
# INFO:tensorflow:loss = 0.6491664, step = 1400 (0.158 sec)
# INFO:tensorflow:global_step/sec: 598.913
# INFO:tensorflow:loss = 0.63642573, step = 1500 (0.167 sec)
# INFO:tensorflow:global_step/sec: 645.211
# INFO:tensorflow:loss = 0.62157977, step = 1600 (0.155 sec)
# INFO:tensorflow:global_step/sec: 606.238
# INFO:tensorflow:loss = 0.60312283, step = 1700 (0.165 sec)
# INFO:tensorflow:global_step/sec: 598.911
# INFO:tensorflow:loss = 0.5870704, step = 1800 (0.167 sec)
# INFO:tensorflow:global_step/sec: 584.903
# INFO:tensorflow:loss = 0.5765788, step = 1900 (0.174 sec)
# INFO:tensorflow:global_step/sec: 518.227
# INFO:tensorflow:loss = 0.556962, step = 2000 (0.190 sec)
# INFO:tensorflow:global_step/sec: 581.504
# INFO:tensorflow:loss = 0.55520487, step = 2100 (0.172 sec)
# INFO:tensorflow:global_step/sec: 607.987
# INFO:tensorflow:loss = 0.5455533, step = 2200 (0.165 sec)
# INFO:tensorflow:global_step/sec: 558.564
# INFO:tensorflow:loss = 0.53600985, step = 2300 (0.179 sec)
# INFO:tensorflow:global_step/sec: 637.22
# INFO:tensorflow:loss = 0.5189329, step = 2400 (0.157 sec)
# INFO:tensorflow:global_step/sec: 548.022
# INFO:tensorflow:loss = 0.5076389, step = 2500 (0.183 sec)
# INFO:tensorflow:global_step/sec: 584.088
# INFO:tensorflow:loss = 0.4984594, step = 2600 (0.174 sec)
# INFO:tensorflow:global_step/sec: 473.826
# INFO:tensorflow:loss = 0.4885497, step = 2700 (0.208 sec)
# INFO:tensorflow:global_step/sec: 675.075
# INFO:tensorflow:loss = 0.49463186, step = 2800 (0.149 sec)
# INFO:tensorflow:global_step/sec: 625.473
# INFO:tensorflow:loss = 0.470185, step = 2900 (0.160 sec)
# INFO:tensorflow:global_step/sec: 640.113
# INFO:tensorflow:loss = 0.47089356, step = 3000 (0.155 sec)
# INFO:tensorflow:global_step/sec: 607.148
# INFO:tensorflow:loss = 0.4683144, step = 3100 (0.165 sec)
# INFO:tensorflow:global_step/sec: 604.889
# INFO:tensorflow:loss = 0.46701258, step = 3200 (0.165 sec)
# INFO:tensorflow:global_step/sec: 654.563
# INFO:tensorflow:loss = 0.44826812, step = 3300 (0.154 sec)
# INFO:tensorflow:global_step/sec: 607.116
# INFO:tensorflow:loss = 0.448, step = 3400 (0.164 sec)
# INFO:tensorflow:global_step/sec: 651.458
# INFO:tensorflow:loss = 0.43691355, step = 3500 (0.154 sec)
# INFO:tensorflow:global_step/sec: 659.341
# INFO:tensorflow:loss = 0.4318096, step = 3600 (0.151 sec)
# INFO:tensorflow:global_step/sec: 628.765
# INFO:tensorflow:loss = 0.42466915, step = 3700 (0.160 sec)
# INFO:tensorflow:global_step/sec: 617.278
# INFO:tensorflow:loss = 0.4213874, step = 3800 (0.163 sec)
# INFO:tensorflow:global_step/sec: 575.298
# INFO:tensorflow:loss = 0.4131536, step = 3900 (0.172 sec)
# INFO:tensorflow:global_step/sec: 666.809
# INFO:tensorflow:loss = 0.4068355, step = 4000 (0.150 sec)
# INFO:tensorflow:global_step/sec: 606.366
# INFO:tensorflow:loss = 0.40173414, step = 4100 (0.166 sec)
# INFO:tensorflow:global_step/sec: 499.484
# INFO:tensorflow:loss = 0.39986968, step = 4200 (0.200 sec)
# INFO:tensorflow:global_step/sec: 637.082
# INFO:tensorflow:loss = 0.39332557, step = 4300 (0.156 sec)
# INFO:tensorflow:global_step/sec: 595.434
# INFO:tensorflow:loss = 0.3888294, step = 4400 (0.168 sec)
# INFO:tensorflow:global_step/sec: 593.707
# INFO:tensorflow:loss = 0.38219154, step = 4500 (0.169 sec)
# INFO:tensorflow:global_step/sec: 642.669
# INFO:tensorflow:loss = 0.3797945, step = 4600 (0.156 sec)
# INFO:tensorflow:global_step/sec: 619.809
# INFO:tensorflow:loss = 0.37801474, step = 4700 (0.160 sec)
# INFO:tensorflow:global_step/sec: 570.534
# INFO:tensorflow:loss = 0.37124756, step = 4800 (0.175 sec)
# INFO:tensorflow:global_step/sec: 594.312
# INFO:tensorflow:loss = 0.37271047, step = 4900 (0.168 sec)
# INFO:tensorflow:global_step/sec: 546.979
# INFO:tensorflow:loss = 0.36714154, step = 5000 (0.183 sec)
# INFO:tensorflow:global_step/sec: 595.454
# INFO:tensorflow:loss = 0.3626302, step = 5100 (0.168 sec)
# INFO:tensorflow:global_step/sec: 580.582
# INFO:tensorflow:loss = 0.35254106, step = 5200 (0.172 sec)
# INFO:tensorflow:global_step/sec: 659.47
# INFO:tensorflow:loss = 0.34966898, step = 5300 (0.153 sec)
# INFO:tensorflow:global_step/sec: 478.56
# INFO:tensorflow:loss = 0.34886098, step = 5400 (0.208 sec)
# INFO:tensorflow:global_step/sec: 665.699
# INFO:tensorflow:loss = 0.3532167, step = 5500 (0.151 sec)
# INFO:tensorflow:global_step/sec: 637.896
# INFO:tensorflow:loss = 0.33451182, step = 5600 (0.159 sec)
# INFO:tensorflow:global_step/sec: 658.385
# INFO:tensorflow:loss = 0.34364116, step = 5700 (0.150 sec)
# INFO:tensorflow:global_step/sec: 613.482
# INFO:tensorflow:loss = 0.34201318, step = 5800 (0.162 sec)
# INFO:tensorflow:global_step/sec: 577.996
# INFO:tensorflow:loss = 0.3252855, step = 5900 (0.173 sec)
# INFO:tensorflow:global_step/sec: 625.214
# INFO:tensorflow:loss = 0.33076966, step = 6000 (0.160 sec)
# INFO:tensorflow:global_step/sec: 598.58
# INFO:tensorflow:loss = 0.3202761, step = 6100 (0.168 sec)
# INFO:tensorflow:global_step/sec: 658.08
# INFO:tensorflow:loss = 0.3210294, step = 6200 (0.152 sec)
# INFO:tensorflow:global_step/sec: 632.815
# INFO:tensorflow:loss = 0.32279924, step = 6300 (0.158 sec)
# INFO:tensorflow:global_step/sec: 595.641
# INFO:tensorflow:loss = 0.31878686, step = 6400 (0.167 sec)
# INFO:tensorflow:global_step/sec: 638.945
# INFO:tensorflow:loss = 0.31547642, step = 6500 (0.157 sec)
# INFO:tensorflow:global_step/sec: 630.654
# INFO:tensorflow:loss = 0.3165695, step = 6600 (0.159 sec)
# INFO:tensorflow:global_step/sec: 588.825
# INFO:tensorflow:loss = 0.3052078, step = 6700 (0.170 sec)
# INFO:tensorflow:global_step/sec: 595.214
# INFO:tensorflow:loss = 0.3074215, step = 6800 (0.168 sec)
# INFO:tensorflow:global_step/sec: 667.193
# INFO:tensorflow:loss = 0.30360633, step = 6900 (0.151 sec)
# INFO:tensorflow:global_step/sec: 656.671
# INFO:tensorflow:loss = 0.30900607, step = 7000 (0.152 sec)
# INFO:tensorflow:global_step/sec: 592.557
# INFO:tensorflow:loss = 0.30098528, step = 7100 (0.172 sec)
# INFO:tensorflow:global_step/sec: 617.482
# INFO:tensorflow:loss = 0.29903507, step = 7200 (0.159 sec)
# INFO:tensorflow:global_step/sec: 595.342
# INFO:tensorflow:loss = 0.30311555, step = 7300 (0.168 sec)
# INFO:tensorflow:global_step/sec: 564.934
# INFO:tensorflow:loss = 0.29400623, step = 7400 (0.177 sec)
# INFO:tensorflow:global_step/sec: 613.788
# INFO:tensorflow:loss = 0.29036713, step = 7500 (0.164 sec)
# INFO:tensorflow:global_step/sec: 566.773
# INFO:tensorflow:loss = 0.279324, step = 7600 (0.175 sec)
# INFO:tensorflow:global_step/sec: 560.085
# INFO:tensorflow:loss = 0.2820799, step = 7700 (0.179 sec)
# INFO:tensorflow:global_step/sec: 653.965
# INFO:tensorflow:loss = 0.2878836, step = 7800 (0.153 sec)
# INFO:tensorflow:global_step/sec: 588.804
# INFO:tensorflow:loss = 0.2835405, step = 7900 (0.170 sec)
# INFO:tensorflow:global_step/sec: 616.351
# INFO:tensorflow:loss = 0.2811526, step = 8000 (0.163 sec)
# INFO:tensorflow:global_step/sec: 617.936
# INFO:tensorflow:loss = 0.28031015, step = 8100 (0.161 sec)
# INFO:tensorflow:global_step/sec: 641.514
# INFO:tensorflow:loss = 0.26697797, step = 8200 (0.156 sec)
# INFO:tensorflow:global_step/sec: 602.015
# INFO:tensorflow:loss = 0.2784584, step = 8300 (0.167 sec)
# INFO:tensorflow:global_step/sec: 662.463
# INFO:tensorflow:loss = 0.27796397, step = 8400 (0.150 sec)
# INFO:tensorflow:global_step/sec: 625.52
# INFO:tensorflow:loss = 0.2715818, step = 8500 (0.160 sec)
# INFO:tensorflow:global_step/sec: 598.902
# INFO:tensorflow:loss = 0.2640094, step = 8600 (0.167 sec)
# INFO:tensorflow:global_step/sec: 612.971
# INFO:tensorflow:loss = 0.2673399, step = 8700 (0.165 sec)
# INFO:tensorflow:global_step/sec: 619.842
# INFO:tensorflow:loss = 0.26675004, step = 8800 (0.159 sec)
# INFO:tensorflow:global_step/sec: 582.881
# INFO:tensorflow:loss = 0.25739905, step = 8900 (0.174 sec)
# INFO:tensorflow:global_step/sec: 483.404
# INFO:tensorflow:loss = 0.2604736, step = 9000 (0.205 sec)
# INFO:tensorflow:global_step/sec: 613.887
# INFO:tensorflow:loss = 0.25829858, step = 9100 (0.164 sec)
# INFO:tensorflow:global_step/sec: 577.507
# INFO:tensorflow:loss = 0.255167, step = 9200 (0.172 sec)
# INFO:tensorflow:global_step/sec: 667.094
# INFO:tensorflow:loss = 0.2628495, step = 9300 (0.150 sec)
# INFO:tensorflow:global_step/sec: 632.875
# INFO:tensorflow:loss = 0.26408198, step = 9400 (0.159 sec)
# INFO:tensorflow:global_step/sec: 569.922
# INFO:tensorflow:loss = 0.2509421, step = 9500 (0.174 sec)
# INFO:tensorflow:global_step/sec: 643.475
# INFO:tensorflow:loss = 0.2510512, step = 9600 (0.156 sec)
# INFO:tensorflow:global_step/sec: 617.429
# INFO:tensorflow:loss = 0.25316912, step = 9700 (0.161 sec)
# INFO:tensorflow:global_step/sec: 632.874
# INFO:tensorflow:loss = 0.24290016, step = 9800 (0.159 sec)
# INFO:tensorflow:global_step/sec: 624.959
# INFO:tensorflow:loss = 0.24998626, step = 9900 (0.159 sec)
# INFO:tensorflow:global_step/sec: 556.116
# INFO:tensorflow:loss = 0.24859466, step = 10000 (0.180 sec)
# INFO:tensorflow:global_step/sec: 605.725
# INFO:tensorflow:loss = 0.24528632, step = 10100 (0.166 sec)
# INFO:tensorflow:global_step/sec: 653.363
# INFO:tensorflow:loss = 0.23823245, step = 10200 (0.152 sec)
# INFO:tensorflow:global_step/sec: 681.011
# INFO:tensorflow:loss = 0.24144137, step = 10300 (0.148 sec)
# INFO:tensorflow:global_step/sec: 632.94
# INFO:tensorflow:loss = 0.24146624, step = 10400 (0.159 sec)
# INFO:tensorflow:global_step/sec: 633.186
# INFO:tensorflow:loss = 0.23976548, step = 10500 (0.156 sec)
# INFO:tensorflow:global_step/sec: 677.391
# INFO:tensorflow:loss = 0.23930897, step = 10600 (0.147 sec)
# INFO:tensorflow:global_step/sec: 647.465
# INFO:tensorflow:loss = 0.22927333, step = 10700 (0.155 sec)
# INFO:tensorflow:global_step/sec: 599.235
# INFO:tensorflow:loss = 0.23300338, step = 10800 (0.167 sec)
# INFO:tensorflow:global_step/sec: 608.382
# INFO:tensorflow:loss = 0.2327658, step = 10900 (0.164 sec)
# INFO:tensorflow:global_step/sec: 618.638
# INFO:tensorflow:loss = 0.23672774, step = 11000 (0.163 sec)
# INFO:tensorflow:global_step/sec: 617.331
# INFO:tensorflow:loss = 0.23178151, step = 11100 (0.161 sec)
# INFO:tensorflow:global_step/sec: 599.292
# INFO:tensorflow:loss = 0.22259456, step = 11200 (0.167 sec)
# INFO:tensorflow:global_step/sec: 562.22
# INFO:tensorflow:loss = 0.22260234, step = 11300 (0.178 sec)
# INFO:tensorflow:global_step/sec: 540.642
# INFO:tensorflow:loss = 0.22995457, step = 11400 (0.185 sec)
# INFO:tensorflow:global_step/sec: 636.236
# INFO:tensorflow:loss = 0.22081251, step = 11500 (0.157 sec)
# INFO:tensorflow:global_step/sec: 599.6
# INFO:tensorflow:loss = 0.2215789, step = 11600 (0.169 sec)
# INFO:tensorflow:global_step/sec: 587.684
# INFO:tensorflow:loss = 0.216705, step = 11700 (0.168 sec)
# INFO:tensorflow:global_step/sec: 598.894
# INFO:tensorflow:loss = 0.22008525, step = 11800 (0.167 sec)
# INFO:tensorflow:global_step/sec: 611.806
# INFO:tensorflow:loss = 0.21751466, step = 11900 (0.165 sec)
# INFO:tensorflow:global_step/sec: 631.26
# INFO:tensorflow:loss = 0.21683809, step = 12000 (0.157 sec)
# INFO:tensorflow:global_step/sec: 676.012
# INFO:tensorflow:loss = 0.2092602, step = 12100 (0.147 sec)
# INFO:tensorflow:global_step/sec: 616.287
# INFO:tensorflow:loss = 0.22080654, step = 12200 (0.163 sec)
# INFO:tensorflow:global_step/sec: 581.346
# INFO:tensorflow:loss = 0.2207689, step = 12300 (0.171 sec)
# INFO:tensorflow:global_step/sec: 603.612
# INFO:tensorflow:loss = 0.21936515, step = 12400 (0.166 sec)
# INFO:tensorflow:global_step/sec: 555.734
# INFO:tensorflow:loss = 0.21150675, step = 12500 (0.180 sec)
# INFO:tensorflow:global_step/sec: 624.849
# INFO:tensorflow:loss = 0.21428847, step = 12600 (0.161 sec)
# INFO:tensorflow:global_step/sec: 617.503
# INFO:tensorflow:loss = 0.20433983, step = 12700 (0.162 sec)
# INFO:tensorflow:global_step/sec: 662.608
# INFO:tensorflow:loss = 0.21091296, step = 12800 (0.150 sec)
# INFO:tensorflow:global_step/sec: 666.136
# INFO:tensorflow:loss = 0.2140656, step = 12900 (0.150 sec)
# INFO:tensorflow:global_step/sec: 457.713
# INFO:tensorflow:loss = 0.20170164, step = 13000 (0.219 sec)
# INFO:tensorflow:global_step/sec: 619.823
# INFO:tensorflow:loss = 0.216449, step = 13100 (0.161 sec)
# INFO:tensorflow:global_step/sec: 606.034
# INFO:tensorflow:loss = 0.20780161, step = 13200 (0.166 sec)
# INFO:tensorflow:global_step/sec: 628.911
# INFO:tensorflow:loss = 0.19803849, step = 13300 (0.161 sec)
# INFO:tensorflow:global_step/sec: 613.848
# INFO:tensorflow:loss = 0.20586258, step = 13400 (0.159 sec)
# INFO:tensorflow:global_step/sec: 661.421
# INFO:tensorflow:loss = 0.20528032, step = 13500 (0.152 sec)
# INFO:tensorflow:global_step/sec: 633.871
# INFO:tensorflow:loss = 0.1918604, step = 13600 (0.159 sec)
# INFO:tensorflow:global_step/sec: 628.065
# INFO:tensorflow:loss = 0.201224, step = 13700 (0.159 sec)
# INFO:tensorflow:global_step/sec: 567.002
# INFO:tensorflow:loss = 0.19693233, step = 13800 (0.176 sec)
# INFO:tensorflow:global_step/sec: 687.929
# INFO:tensorflow:loss = 0.20808572, step = 13900 (0.146 sec)
# INFO:tensorflow:global_step/sec: 645.087
# INFO:tensorflow:loss = 0.19879538, step = 14000 (0.154 sec)
# INFO:tensorflow:global_step/sec: 578.29
# INFO:tensorflow:loss = 0.19800259, step = 14100 (0.173 sec)
# INFO:tensorflow:global_step/sec: 602.674
# INFO:tensorflow:loss = 0.2014237, step = 14200 (0.166 sec)
# INFO:tensorflow:global_step/sec: 572.97
# INFO:tensorflow:loss = 0.18861918, step = 14300 (0.176 sec)
# INFO:tensorflow:global_step/sec: 651.92
# INFO:tensorflow:loss = 0.19559097, step = 14400 (0.151 sec)
# INFO:tensorflow:global_step/sec: 621.227
# INFO:tensorflow:loss = 0.20181733, step = 14500 (0.163 sec)
# INFO:tensorflow:global_step/sec: 615.19
# INFO:tensorflow:loss = 0.19197747, step = 14600 (0.162 sec)
# INFO:tensorflow:global_step/sec: 545.537
# INFO:tensorflow:loss = 0.1882002, step = 14700 (0.182 sec)
# INFO:tensorflow:global_step/sec: 628.071
# INFO:tensorflow:loss = 0.18570942, step = 14800 (0.159 sec)
# INFO:tensorflow:global_step/sec: 582.111
# INFO:tensorflow:loss = 0.18675818, step = 14900 (0.172 sec)
# INFO:tensorflow:global_step/sec: 550.2
# INFO:tensorflow:loss = 0.1872891, step = 15000 (0.182 sec)
# INFO:tensorflow:global_step/sec: 637.051
# INFO:tensorflow:loss = 0.19052735, step = 15100 (0.159 sec)
# INFO:tensorflow:global_step/sec: 629.053
# INFO:tensorflow:loss = 0.18862492, step = 15200 (0.157 sec)
# INFO:tensorflow:global_step/sec: 609.864
# INFO:tensorflow:loss = 0.19115388, step = 15300 (0.164 sec)
# INFO:tensorflow:global_step/sec: 606.14
# INFO:tensorflow:loss = 0.18968427, step = 15400 (0.165 sec)
# INFO:tensorflow:global_step/sec: 630.531
# INFO:tensorflow:loss = 0.18926048, step = 15500 (0.159 sec)
# INFO:tensorflow:global_step/sec: 581.492
# INFO:tensorflow:loss = 0.18691425, step = 15600 (0.174 sec)
# INFO:tensorflow:global_step/sec: 637.069
# INFO:tensorflow:loss = 0.18161765, step = 15700 (0.155 sec)
# INFO:tensorflow:global_step/sec: 633.003
# INFO:tensorflow:loss = 0.18476859, step = 15800 (0.160 sec)
# INFO:tensorflow:global_step/sec: 588.359
# INFO:tensorflow:loss = 0.18348652, step = 15900 (0.168 sec)
# INFO:tensorflow:global_step/sec: 602.403
# INFO:tensorflow:loss = 0.18040308, step = 16000 (0.166 sec)
# INFO:tensorflow:global_step/sec: 604.105
# INFO:tensorflow:loss = 0.18804897, step = 16100 (0.167 sec)
# INFO:tensorflow:global_step/sec: 617.426
# INFO:tensorflow:loss = 0.17952478, step = 16200 (0.161 sec)
# INFO:tensorflow:global_step/sec: 578.03
# INFO:tensorflow:loss = 0.18167803, step = 16300 (0.174 sec)
# INFO:tensorflow:global_step/sec: 661.122
# INFO:tensorflow:loss = 0.17795688, step = 16400 (0.151 sec)
# INFO:tensorflow:global_step/sec: 630.952
# INFO:tensorflow:loss = 0.17527051, step = 16500 (0.157 sec)
# INFO:tensorflow:global_step/sec: 570.37
# INFO:tensorflow:loss = 0.18230286, step = 16600 (0.175 sec)
# INFO:tensorflow:global_step/sec: 609.726
# INFO:tensorflow:loss = 0.170937, step = 16700 (0.165 sec)
# INFO:tensorflow:global_step/sec: 394.804
# INFO:tensorflow:loss = 0.17189251, step = 16800 (0.252 sec)
# INFO:tensorflow:global_step/sec: 665.044
# INFO:tensorflow:loss = 0.16809538, step = 16900 (0.150 sec)
# INFO:tensorflow:global_step/sec: 602.834
# INFO:tensorflow:loss = 0.17845285, step = 17000 (0.167 sec)
# INFO:tensorflow:global_step/sec: 538.514
# INFO:tensorflow:loss = 0.16974528, step = 17100 (0.185 sec)
# INFO:tensorflow:global_step/sec: 652.892
# INFO:tensorflow:loss = 0.16075268, step = 17200 (0.153 sec)
# INFO:tensorflow:global_step/sec: 612.852
# INFO:tensorflow:loss = 0.16310346, step = 17300 (0.163 sec)
# INFO:tensorflow:global_step/sec: 611.29
# INFO:tensorflow:loss = 0.16521353, step = 17400 (0.164 sec)
# INFO:tensorflow:global_step/sec: 638.876
# INFO:tensorflow:loss = 0.16245222, step = 17500 (0.156 sec)
# INFO:tensorflow:global_step/sec: 585.131
# INFO:tensorflow:loss = 0.15980026, step = 17600 (0.173 sec)
# INFO:tensorflow:global_step/sec: 633.068
# INFO:tensorflow:loss = 0.16659693, step = 17700 (0.156 sec)
# INFO:tensorflow:global_step/sec: 594.754
# INFO:tensorflow:loss = 0.16763043, step = 17800 (0.168 sec)
# INFO:tensorflow:global_step/sec: 593.186
# INFO:tensorflow:loss = 0.16121414, step = 17900 (0.169 sec)
# INFO:tensorflow:global_step/sec: 543.576
# INFO:tensorflow:loss = 0.16921297, step = 18000 (0.184 sec)
# INFO:tensorflow:global_step/sec: 613.61
# INFO:tensorflow:loss = 0.14777924, step = 18100 (0.163 sec)
# INFO:tensorflow:global_step/sec: 635.27
# INFO:tensorflow:loss = 0.15566534, step = 18200 (0.158 sec)
# INFO:tensorflow:global_step/sec: 553.081
# INFO:tensorflow:loss = 0.1584634, step = 18300 (0.180 sec)
# INFO:tensorflow:global_step/sec: 526.412
# INFO:tensorflow:loss = 0.1666697, step = 18400 (0.190 sec)
# INFO:tensorflow:global_step/sec: 634.133
# INFO:tensorflow:loss = 0.15376571, step = 18500 (0.158 sec)
# INFO:tensorflow:global_step/sec: 592.976
# INFO:tensorflow:loss = 0.15911853, step = 18600 (0.169 sec)
# INFO:tensorflow:global_step/sec: 580.454
# INFO:tensorflow:loss = 0.15337858, step = 18700 (0.173 sec)
# INFO:tensorflow:global_step/sec: 669.323
# INFO:tensorflow:loss = 0.15964782, step = 18800 (0.149 sec)
# INFO:tensorflow:global_step/sec: 668.689
# INFO:tensorflow:loss = 0.14952594, step = 18900 (0.149 sec)
# INFO:tensorflow:global_step/sec: 630.371
# INFO:tensorflow:loss = 0.15052915, step = 19000 (0.159 sec)
# INFO:tensorflow:global_step/sec: 582.471
# INFO:tensorflow:loss = 0.16189417, step = 19100 (0.174 sec)
# INFO:tensorflow:global_step/sec: 633.066
# INFO:tensorflow:loss = 0.1536952, step = 19200 (0.156 sec)
# INFO:tensorflow:global_step/sec: 598.81
# INFO:tensorflow:loss = 0.1411595, step = 19300 (0.168 sec)
# INFO:tensorflow:global_step/sec: 597.189
# INFO:tensorflow:loss = 0.14362471, step = 19400 (0.166 sec)
# INFO:tensorflow:global_step/sec: 601.796
# INFO:tensorflow:loss = 0.15204918, step = 19500 (0.166 sec)
# INFO:tensorflow:global_step/sec: 582.498
# INFO:tensorflow:loss = 0.14661813, step = 19600 (0.171 sec)
# INFO:tensorflow:global_step/sec: 589.729
# INFO:tensorflow:loss = 0.14411068, step = 19700 (0.171 sec)
# INFO:tensorflow:global_step/sec: 561.32
# INFO:tensorflow:loss = 0.149881, step = 19800 (0.178 sec)
# INFO:tensorflow:global_step/sec: 668.356
# INFO:tensorflow:loss = 0.1387457, step = 19900 (0.150 sec)
# INFO:tensorflow:global_step/sec: 643.101
# INFO:tensorflow:loss = 0.14355728, step = 20000 (0.155 sec)
# INFO:tensorflow:global_step/sec: 434.307
# INFO:tensorflow:loss = 0.14490196, step = 20100 (0.230 sec)
# INFO:tensorflow:global_step/sec: 621.232
# INFO:tensorflow:loss = 0.15010044, step = 20200 (0.162 sec)
# INFO:tensorflow:global_step/sec: 666.788
# INFO:tensorflow:loss = 0.14108983, step = 20300 (0.149 sec)
# INFO:tensorflow:global_step/sec: 595.329
# INFO:tensorflow:loss = 0.14649734, step = 20400 (0.168 sec)
# INFO:tensorflow:global_step/sec: 606.186
# INFO:tensorflow:loss = 0.15035628, step = 20500 (0.165 sec)
# INFO:tensorflow:global_step/sec: 658.015
# INFO:tensorflow:loss = 0.1491206, step = 20600 (0.152 sec)
# INFO:tensorflow:global_step/sec: 633.027
# INFO:tensorflow:loss = 0.14383915, step = 20700 (0.161 sec)
# INFO:tensorflow:global_step/sec: 602.521
# INFO:tensorflow:loss = 0.13720399, step = 20800 (0.164 sec)
# INFO:tensorflow:global_step/sec: 615.282
# INFO:tensorflow:loss = 0.15474282, step = 20900 (0.161 sec)
# INFO:tensorflow:global_step/sec: 568.071
# INFO:tensorflow:loss = 0.13990253, step = 21000 (0.176 sec)
# INFO:tensorflow:global_step/sec: 671.543
# INFO:tensorflow:loss = 0.13640843, step = 21100 (0.149 sec)
# INFO:tensorflow:global_step/sec: 629.062
# INFO:tensorflow:loss = 0.14156087, step = 21200 (0.159 sec)
# INFO:tensorflow:global_step/sec: 578.086
# INFO:tensorflow:loss = 0.13480869, step = 21300 (0.174 sec)
# INFO:tensorflow:global_step/sec: 609.877
# INFO:tensorflow:loss = 0.13964415, step = 21400 (0.166 sec)
# INFO:tensorflow:global_step/sec: 568.252
# INFO:tensorflow:loss = 0.14160538, step = 21500 (0.173 sec)
# INFO:tensorflow:global_step/sec: 598.729
# INFO:tensorflow:loss = 0.13388559, step = 21600 (0.168 sec)
# INFO:tensorflow:global_step/sec: 591.79
# INFO:tensorflow:loss = 0.14647901, step = 21700 (0.169 sec)
# INFO:tensorflow:global_step/sec: 581.47
# INFO:tensorflow:loss = 0.13169129, step = 21800 (0.174 sec)
# INFO:tensorflow:global_step/sec: 540.597
# INFO:tensorflow:loss = 0.13351369, step = 21900 (0.182 sec)
# INFO:tensorflow:global_step/sec: 625.098
# INFO:tensorflow:loss = 0.13539092, step = 22000 (0.160 sec)
# INFO:tensorflow:global_step/sec: 565.02
# INFO:tensorflow:loss = 0.13029192, step = 22100 (0.178 sec)
# INFO:tensorflow:global_step/sec: 581.497
# INFO:tensorflow:loss = 0.13703206, step = 22200 (0.171 sec)
# INFO:tensorflow:global_step/sec: 625.031
# INFO:tensorflow:loss = 0.12734741, step = 22300 (0.161 sec)
# INFO:tensorflow:global_step/sec: 613.621
# INFO:tensorflow:loss = 0.1346207, step = 22400 (0.164 sec)
# INFO:tensorflow:global_step/sec: 602.485
# INFO:tensorflow:loss = 0.13738683, step = 22500 (0.166 sec)
# INFO:tensorflow:global_step/sec: 606.14
# INFO:tensorflow:loss = 0.12825355, step = 22600 (0.163 sec)
# INFO:tensorflow:global_step/sec: 606.041
# INFO:tensorflow:loss = 0.1295695, step = 22700 (0.165 sec)
# INFO:tensorflow:global_step/sec: 653.68
# INFO:tensorflow:loss = 0.12657191, step = 22800 (0.154 sec)
# INFO:tensorflow:global_step/sec: 632.988
# INFO:tensorflow:loss = 0.13057882, step = 22900 (0.157 sec)
# INFO:tensorflow:global_step/sec: 606.12
# INFO:tensorflow:loss = 0.1328413, step = 23000 (0.166 sec)
# INFO:tensorflow:global_step/sec: 629.036
# INFO:tensorflow:loss = 0.1324568, step = 23100 (0.158 sec)
# INFO:tensorflow:global_step/sec: 571.499
# INFO:tensorflow:loss = 0.113619775, step = 23200 (0.175 sec)
# INFO:tensorflow:global_step/sec: 645.246
# INFO:tensorflow:loss = 0.1238357, step = 23300 (0.155 sec)
# INFO:tensorflow:global_step/sec: 534.828
# INFO:tensorflow:loss = 0.12601653, step = 23400 (0.191 sec)
# INFO:tensorflow:global_step/sec: 637.024
# INFO:tensorflow:loss = 0.12918907, step = 23500 (0.154 sec)
# INFO:tensorflow:global_step/sec: 637.025
# INFO:tensorflow:loss = 0.13868074, step = 23600 (0.156 sec)
# INFO:tensorflow:global_step/sec: 574.773
# INFO:tensorflow:loss = 0.12787607, step = 23700 (0.176 sec)
# INFO:tensorflow:global_step/sec: 434.847
# INFO:tensorflow:loss = 0.122369215, step = 23800 (0.229 sec)
# INFO:tensorflow:global_step/sec: 641.104
# INFO:tensorflow:loss = 0.1244506, step = 23900 (0.155 sec)
# INFO:tensorflow:global_step/sec: 578.108
# INFO:tensorflow:loss = 0.12560093, step = 24000 (0.173 sec)
# INFO:tensorflow:global_step/sec: 584.87
# INFO:tensorflow:loss = 0.11714301, step = 24100 (0.175 sec)
# INFO:tensorflow:global_step/sec: 666.754
# INFO:tensorflow:loss = 0.1293427, step = 24200 (0.146 sec)
# INFO:tensorflow:global_step/sec: 642.876
# INFO:tensorflow:loss = 0.13028458, step = 24300 (0.157 sec)
# INFO:tensorflow:global_step/sec: 546.535
# INFO:tensorflow:loss = 0.12176397, step = 24400 (0.182 sec)
# INFO:tensorflow:global_step/sec: 584.871
# INFO:tensorflow:loss = 0.12242025, step = 24500 (0.171 sec)
# INFO:tensorflow:global_step/sec: 591.731
# INFO:tensorflow:loss = 0.12836452, step = 24600 (0.169 sec)
# INFO:tensorflow:global_step/sec: 633.695
# INFO:tensorflow:loss = 0.12653393, step = 24700 (0.158 sec)
# INFO:tensorflow:global_step/sec: 624.689
# INFO:tensorflow:loss = 0.124771, step = 24800 (0.160 sec)
# INFO:tensorflow:global_step/sec: 610.398
# INFO:tensorflow:loss = 0.11834228, step = 24900 (0.164 sec)
# INFO:tensorflow:global_step/sec: 650.553
# INFO:tensorflow:loss = 0.12440884, step = 25000 (0.154 sec)
# INFO:tensorflow:global_step/sec: 687.002
# INFO:tensorflow:loss = 0.12114467, step = 25100 (0.147 sec)
# INFO:tensorflow:global_step/sec: 623.118
# INFO:tensorflow:loss = 0.11988774, step = 25200 (0.161 sec)
# INFO:tensorflow:global_step/sec: 638.837
# INFO:tensorflow:loss = 0.123402685, step = 25300 (0.155 sec)
# INFO:tensorflow:global_step/sec: 644.986
# INFO:tensorflow:loss = 0.12057917, step = 25400 (0.155 sec)
# INFO:tensorflow:global_step/sec: 604.232
# INFO:tensorflow:loss = 0.12329309, step = 25500 (0.166 sec)
# INFO:tensorflow:global_step/sec: 608.079
# INFO:tensorflow:loss = 0.12128087, step = 25600 (0.163 sec)
# INFO:tensorflow:global_step/sec: 617.357
# INFO:tensorflow:loss = 0.10900646, step = 25700 (0.163 sec)
# INFO:tensorflow:global_step/sec: 503.61
# INFO:tensorflow:loss = 0.11923863, step = 25800 (0.198 sec)
# INFO:tensorflow:global_step/sec: 658.034
# INFO:tensorflow:loss = 0.11383332, step = 25900 (0.152 sec)
# INFO:tensorflow:global_step/sec: 645.244
# INFO:tensorflow:loss = 0.11508399, step = 26000 (0.155 sec)
# INFO:tensorflow:global_step/sec: 606.137
# INFO:tensorflow:loss = 0.11618848, step = 26100 (0.165 sec)
# INFO:tensorflow:global_step/sec: 624.707
# INFO:tensorflow:loss = 0.11964844, step = 26200 (0.161 sec)
# INFO:tensorflow:global_step/sec: 581.508
# INFO:tensorflow:loss = 0.10837443, step = 26300 (0.171 sec)
# INFO:tensorflow:global_step/sec: 662.336
# INFO:tensorflow:loss = 0.114826225, step = 26400 (0.151 sec)
# INFO:tensorflow:global_step/sec: 602.395
# INFO:tensorflow:loss = 0.118971504, step = 26500 (0.166 sec)
# INFO:tensorflow:global_step/sec: 588.313
# INFO:tensorflow:loss = 0.119210504, step = 26600 (0.170 sec)
# INFO:tensorflow:global_step/sec: 597.004
# INFO:tensorflow:loss = 0.115346774, step = 26700 (0.168 sec)
# INFO:tensorflow:global_step/sec: 546.518
# INFO:tensorflow:loss = 0.12099968, step = 26800 (0.183 sec)
# INFO:tensorflow:global_step/sec: 606.138
# INFO:tensorflow:loss = 0.11499773, step = 26900 (0.165 sec)
# INFO:tensorflow:global_step/sec: 598.865
# INFO:tensorflow:loss = 0.11437665, step = 27000 (0.168 sec)
# INFO:tensorflow:global_step/sec: 595.329
# INFO:tensorflow:loss = 0.11548865, step = 27100 (0.167 sec)
# INFO:tensorflow:global_step/sec: 609.832
# INFO:tensorflow:loss = 0.111114204, step = 27200 (0.164 sec)
# INFO:tensorflow:global_step/sec: 615.306
# INFO:tensorflow:loss = 0.11699633, step = 27300 (0.163 sec)
# INFO:tensorflow:global_step/sec: 629.011
# INFO:tensorflow:loss = 0.1059365, step = 27400 (0.161 sec)
# INFO:tensorflow:global_step/sec: 518.2
# INFO:tensorflow:loss = 0.1095071, step = 27500 (0.191 sec)
# INFO:tensorflow:global_step/sec: 431.091
# INFO:tensorflow:loss = 0.11661517, step = 27600 (0.232 sec)
# INFO:tensorflow:global_step/sec: 568.255
# INFO:tensorflow:loss = 0.11566323, step = 27700 (0.178 sec)
# INFO:tensorflow:global_step/sec: 467.347
# INFO:tensorflow:loss = 0.117848925, step = 27800 (0.212 sec)
# INFO:tensorflow:global_step/sec: 558.616
# INFO:tensorflow:loss = 0.110252574, step = 27900 (0.179 sec)
# INFO:tensorflow:global_step/sec: 593.494
# INFO:tensorflow:loss = 0.119339325, step = 28000 (0.169 sec)
# INFO:tensorflow:global_step/sec: 549.519
# INFO:tensorflow:loss = 0.111543775, step = 28100 (0.181 sec)
# INFO:tensorflow:global_step/sec: 584.871
# INFO:tensorflow:loss = 0.11369003, step = 28200 (0.171 sec)
# INFO:tensorflow:global_step/sec: 584.858
# INFO:tensorflow:loss = 0.10358804, step = 28300 (0.173 sec)
# INFO:tensorflow:global_step/sec: 591.794
# INFO:tensorflow:loss = 0.107225776, step = 28400 (0.167 sec)
# INFO:tensorflow:global_step/sec: 609.798
# INFO:tensorflow:loss = 0.10861769, step = 28500 (0.168 sec)
# INFO:tensorflow:global_step/sec: 561.909
# INFO:tensorflow:loss = 0.10317881, step = 28600 (0.174 sec)
# INFO:tensorflow:global_step/sec: 591.793
# INFO:tensorflow:loss = 0.11363931, step = 28700 (0.171 sec)
# INFO:tensorflow:global_step/sec: 581.434
# INFO:tensorflow:loss = 0.11153813, step = 28800 (0.172 sec)
# INFO:tensorflow:global_step/sec: 578.143
# INFO:tensorflow:loss = 0.10388468, step = 28900 (0.171 sec)
# INFO:tensorflow:global_step/sec: 593.49
# INFO:tensorflow:loss = 0.11461595, step = 29000 (0.169 sec)
# INFO:tensorflow:global_step/sec: 581.391
# INFO:tensorflow:loss = 0.1164259, step = 29100 (0.174 sec)
# INFO:tensorflow:global_step/sec: 581.548
# INFO:tensorflow:loss = 0.1132755, step = 29200 (0.169 sec)
# INFO:tensorflow:global_step/sec: 581.471
# INFO:tensorflow:loss = 0.11577505, step = 29300 (0.172 sec)
# INFO:tensorflow:global_step/sec: 617.051
# INFO:tensorflow:loss = 0.114368655, step = 29400 (0.162 sec)
# INFO:tensorflow:global_step/sec: 629.336
# INFO:tensorflow:loss = 0.11056017, step = 29500 (0.161 sec)
# INFO:tensorflow:global_step/sec: 613.57
# INFO:tensorflow:loss = 0.11706982, step = 29600 (0.161 sec)
# INFO:tensorflow:global_step/sec: 611.673
# INFO:tensorflow:loss = 0.107097715, step = 29700 (0.163 sec)
# INFO:tensorflow:global_step/sec: 619.092
# INFO:tensorflow:loss = 0.11128457, step = 29800 (0.163 sec)
# INFO:tensorflow:global_step/sec: 658.027
# INFO:tensorflow:loss = 0.107721075, step = 29900 (0.152 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 30000...
# INFO:tensorflow:Saving checkpoints for 30000 into C:\Users\samgar\AppData\Local\Temp\tmps_ybtmm1\model.ckpt.
# INFO:tensorflow:C:\Users\samgar\AppData\Local\Temp\tmps_ybtmm1\model.ckpt-30000.data-00000-of-00001
# INFO:tensorflow:0
# INFO:tensorflow:C:\Users\samgar\AppData\Local\Temp\tmps_ybtmm1\model.ckpt-30000.index
# INFO:tensorflow:0
# INFO:tensorflow:C:\Users\samgar\AppData\Local\Temp\tmps_ybtmm1\model.ckpt-30000.meta
# INFO:tensorflow:100
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 30000...
# INFO:tensorflow:Loss for final step: 0.10511528.

# %% [markdown]
# The only thing to explain here is the **steps** argument. This simply tells the classifier to run for 5000 steps. Try modifiying this and seeing if your results change. Keep in mind that more is not always better.

# %% [markdown]
# ### Evaluation
# Now let's see how this trained model does!

# %%
eval_result = classifier.evaluate(
    input_fn=lambda: input_fn(test, test_y, training=False))

print('\nTest set accuracy: {accuracy:0.3f}\n'.format(**eval_result))
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2022-08-30T14:56:43
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from C:\Users\samgar\AppData\Local\Temp\tmps_ybtmm1\model.ckpt-30000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 0.21972s
# INFO:tensorflow:Finished evaluation at 2022-08-30-14:56:43
# INFO:tensorflow:Saving dict for global step 30000: accuracy = 0.96666664, average_loss = 0.11940622, global_step = 30000, loss = 0.11940622
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 30000: C:\Users\samgar\AppData\Local\Temp\tmps_ybtmm1\model.ckpt-30000
#
# Test set accuracy: 0.967

# %% [markdown]
# Notice this time we didn't specify the number of steps. This is because during evaluation the model will only look at the testing data one time.

# %% [markdown]
# ### Predictions
# Now that we have a trained model it's time to use it to make predictions. I've written a little script below that allows you to type the features of a flower and see a prediction for its class.

# %%
def input_fn(features, batch_size=256):
    # Convert the inputs to a Dataset without labels.
    return tf.data.Dataset.from_tensor_slices(dict(features)).batch(batch_size)

# features = ['SepalLength', 'SepalWidth', 'PetalLength', 'PetalWidth']
# prediction = {}

# print("Please type numeric values as prompted.")
# for feature in features:
#   valid = True
#   while valid:
#     val = input(feature + ": ")
#     if not val.isdigit(): valid = False


#   prediction[feature] = [float(val)]
prediction = {
    'SepalLength': [8.4],
    'SepalWidth': [6.6],
    'PetalLength': [3.5],
    'PetalWidth': [3.0]
}

predictions = classifier.predict(input_fn=lambda: input_fn(prediction))
for pred_dict in predictions:
    print(pred_dict)
    class_id = pred_dict['class_ids'][0]
    probability = pred_dict['probabilities'][class_id]

    print('Prediction is "{}" ({:.1f}%)'.format(
        SPECIES[class_id], 100 * probability))
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from C:\Users\samgar\AppData\Local\Temp\tmps_ybtmm1\model.ckpt-30000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# {'logits': array([2.0829782, 2.2126398, 0.2822109], dtype=float32), 'probabilities': array([0.43410024, 0.4941984 , 0.07170124], dtype=float32), 'class_ids': array([1], dtype=int64), 'classes': array([b'1'], dtype=object), 'all_class_ids': array([0, 1, 2]), 'all_classes': array([b'0', b'1', b'2'], dtype=object)}
# Prediction is "Versicolor" (49.4%)

# %%
# Here is some example input and expected classes you can try above
expected = ['Setosa', 'Versicolor', 'Virginica']
predict_x = {
    'SepalLength': [5.1, 5.9, 6.9],
    'SepalWidth': [3.3, 3.0, 3.1],
    'PetalLength': [1.7, 4.2, 5.4],
    'PetalWidth': [0.5, 1.5, 2.1],
}

# %% [markdown]
# And that's pretty much it for classification!

# %% [markdown]
# ## Clustering
# Now that we've covered regression and classification it's time to talk about clustering data!
#
# Clustering is a Machine Learning technique that involves the grouping of data points. In theory, data points that are in the same group should have similar properties and/or features, while data points in different groups should have highly dissimilar properties and/or features. (https://towardsdatascience.com/the-5-clustering-algorithms-data-scientists-need-to-know-a36d136ef68)
#
# Unfortunalty there are issues with the current version of TensorFlow and the implementation for KMeans. This means we cannot use KMeans without writing the algorithm from scratch. We aren't quite at that level yet, so we'll just explain the basics of clustering for now.
#
# #### Basic Algorithm for K-Means.
# - Step 1: Randomly pick K points to place K centroids
# - Step 2: Assign all the data points to the centroids by distance. The closest centroid to a point is the one it is assigned to.
# - Step 3: Average all the points belonging to each centroid to find the middle of those clusters (center of mass). Place the corresponding centroids into that position.
# - Step 4: Reassign every point once again to the closest centroid.
# - Step 5: Repeat steps 3-4 until no point changes which centroid it belongs to.
#
# *Please refer to the video for an explanation of KMeans clustering.*

# %% [markdown]
# ## Hidden Markov Models
#
# "The Hidden Markov Model is a finite set of states, each of which is associated with a (generally multidimensional) probability distribution []. Transitions among the states are governed by a set of probabilities called transition probabilities." (http://jedlik.phy.bme.hu/~gerjanos/HMM/node4.html)
#
# A hidden markov model works with probabilities to predict future events or states. In this section we will learn how to create a hidden markov model that can predict the weather.
#
# *This section is based on the following TensorFlow tutorial.* https://www.tensorflow.org/probability/api_docs/python/tfp/distributions/HiddenMarkovModel

# %% [markdown]
# ### Data
# Let's start by discussing the type of data we use when we work with a hidden markov model.
#
# In the previous sections we worked with large datasets of 100's of different entries. For a markov model we are only interested in probability distributions that have to do with states.
#
# We can find these probabilities from large datasets or may already have these values. We'll run through an example in a second that should clear some things up, but let's discuss the components of a markov model.
#
# **States:** In each markov model we have a finite set of states. These states could be something like "warm" and "cold" or "high" and "low" or even "red", "green" and "blue". These states are "hidden" within the model, which means we do not direcly observe them.
#
# **Observations:** Each state has a particular outcome or observation associated with it based on a probability distribution. An example of this is the following: *On a hot day Tim has a 80% chance of being happy and a 20% chance of being sad.*
#
# **Transitions:** Each state will have a probability defining the likelyhood of transitioning to a different state. An example is the following: *a cold day has a 30% chance of being followed by a hot day and a 70% chance of being follwed by another cold day.*
#
# To create a hidden markov model we need.
# - States
# - Observation Distribution
# - Transition Distribution
#
# For our purpose we will assume we already have this information available as we attempt to predict the weather on a given day.

# %% [markdown]
# ### Imports and Setup

# %%
# %tensorflow_version 2.x  # this line is not required unless you are in a notebook
# Out:
# UsageError: Line magic function `%tensorflow_version` not found.

# %% [markdown]
# Due to a version mismatch with tensorflow v2 and tensorflow_probability we need to install the most recent version of tensorflow_probability (see below).

# %%
import tensorflow_probability as tfp  # We are using a different module from tensorflow this time
import tensorflow as tf

# %% [markdown]
# ### Weather Model
# Taken direclty from the TensorFlow documentation (https://www.tensorflow.org/probability/api_docs/python/tfp/distributions/HiddenMarkovModel).
#
# We will model a simple weather system and try to predict the temperature on each day given the following information.
# 1. Cold days are encoded by a 0 and hot days are encoded by a 1.
# 2. The first day in our sequence has an 80% chance of being cold.
# 3. A cold day has a 30% chance of being followed by a hot day.
# 4. A hot day has a 20% chance of being followed by a cold day.
# 5. On each day the temperature is
#  normally distributed with mean and standard deviation 0 and 5 on
#  a cold day and mean and standard deviation 15 and 10 on a hot day.
#
# If you're unfamiliar with **standard deviation** it can be put simply as the range of expected values.
#
# In this example, on a hot day the average temperature is 15 and ranges from 5 to 25.
#
# To model this in TensorFlow we will do the following.

# %%
tfd = tfp.distributions  # making a shortcut for later on
initial_distribution = tfd.Categorical(probs=[0.2, 0.8])  # Refer to point 2 above
transition_distribution = tfd.Categorical(probs=[[0.5, 0.5],
                                                 [0.2, 0.8]])  # refer to points 3 and 4 above
observation_distribution = tfd.Normal(loc=[0., 15.], scale=[5., 10.])  # refer to point 5 above

# the loc argument represents the mean and the scale is the standard devitation

# %% [markdown]
# We've now created distribution variables to model our system and it's time to create the hidden markov model.

# %%
model = tfd.HiddenMarkovModel(
    initial_distribution=initial_distribution,
    transition_distribution=transition_distribution,
    observation_distribution=observation_distribution,
    num_steps=7)

# %% [markdown]
# The number of steps represents the number of days that we would like to predict information for. In this case we've chosen 7, an entire week.
#
# To get the **expected temperatures** on each day we can do the following.

# %%
mean = model.mean()

# due to the way TensorFlow works on a lower level we need to evaluate part of the graph
# from within a session to see the value of this tensor

# in the new version of tensorflow we need to use tf.compat.v1.Session() rather than just tf.Session()
with tf.compat.v1.Session() as sess:  
  print(mean.numpy())
# Out:
# [11.999999 11.1      10.830001 10.748999 10.724698 10.71741  10.715222]

# %% [markdown]
# ## Conclusion
# So that's it for the core learning algorithms in TensorFlow. Hopefully you've learned about a few interesting tools that are easy to use! To practice I'd encourage you to try out some of these algorithms on different datasets.

# %% [markdown]
# ## Sources
#
# 1. Chen, James. “Line Of Best Fit.” Investopedia, Investopedia, 29 Jan. 2020, www.investopedia.com/terms/l/line-of-best-fit.asp.
# 2. “Tf.feature_column.categorical_column_with_vocabulary_list.” TensorFlow, www.tensorflow.org/api_docs/python/tf/feature_column/categorical_column_with_vocabulary_list?version=stable.
# 3. “Build a Linear Model with Estimators &nbsp;: &nbsp; TensorFlow Core.” TensorFlow, www.tensorflow.org/tutorials/estimator/linear.
# 4. Staff, EasyBib. “The Free Automatic Bibliography Composer.” EasyBib, Chegg, 1 Jan. 2020, www.easybib.com/project/style/mla8?id=1582473656_5e52a1b8c84d52.80301186.
# 5. Seif, George. “The 5 Clustering Algorithms Data Scientists Need to Know.” Medium, Towards Data Science, 14 Sept. 2019, https://towardsdatascience.com/the-5-clustering-algorithms-data-scientists-need-to-know-a36d136ef68.
# 6. Definition of Hidden Markov Model, http://jedlik.phy.bme.hu/~gerjanos/HMM/node4.html.
# 7. “Tfp.distributions.HiddenMarkovModel &nbsp;: &nbsp; TensorFlow Probability.” TensorFlow, www.tensorflow.org/probability/api_docs/python/tfp/distributions/HiddenMarkovModel.
